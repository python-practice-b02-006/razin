# %%
import numpy as np
import matplotlib.pyplot as plt


x1 = np.array([45.9, 50.4, 55.3, 61.4, 67.3, 75.0, 82.0, 104.5, 88.3, 77.0, 65.9, 59.6, 54.0])
y1 = np.array([100, 107.5, 117.5, 130, 145, 160, 175, 222.5, 187.5, 161, 140, 125, 115])
UI = (x1*y1).sum()/len(x1)
I2 = (x1**2).sum()/len(x1)
U2 = (y1**2).sum()/len(y1)
R = UI/I2
print(np.sqrt(1/(len(x1)-1)*(U2/I2-R**2)))
pp1, v1 = np.polyfit(x1, y1, deg=1, cov=True)
p1 = np.poly1d(pp1)
x = np.arange(35, 110, 0.01)
plt.plot(x, p1(x),label=r'$l = 20 см$')
xx1 = np.array([45.9, 50.4, 55.3, 61.4, 67.3, 75.0, 82.0])
yy1 = np.array([100, 107.5, 117.5, 130, 145, 160, 175])
plt.plot(xx1,yy1,'.',color='red')
xxx1 = np.array([104.5, 88.3, 77.0, 65.9, 59.6, 54.0])
yyy1 = np.array([222.5, 187.5, 161, 140, 125, 115])
plt.plot(xxx1,yyy1,'x',color='red')


x2 = np.array([46.7, 52.2, 56.2, 70.9, 81.2, 93.8, 99.9, 85.1, 73.0, 64.3, 58, 52.7, 47.8])
y2 = np.array([150, 165, 177.5, 225, 257.5, 295, 315, 270, 230, 202.5, 185, 165, 150])
UI = (x2*y2).sum()/len(x2)
I2 = (x2**2).sum()/len(x2)
U2 = (y2**2).sum()/len(y2)
R = UI/I2
print(np.sqrt(1/(len(x2)-1)*(U2/I2-R**2)))
pp2, v2 = np.polyfit(x2, y2, deg=1, cov=True)
p2 = np.poly1d(pp2)
x = np.arange(0, 110, 0.01)
plt.plot(x, p2(x),label=r'$l = 30 см$')
xx2 = np.array([46.7, 52.2, 56.2, 61.2, 70.9, 81.2, 93.8, 99.9])
yy2 = np.array([150, 165, 177.5, 245, 225, 257.5, 295, 315])
plt.plot(xx2,yy2,'.',color='darkblue')
xxx2 = np.array([85.1, 73.0, 64.3, 58, 52.7, 47.8])
yyy2 = np.array([270, 230, 202.5, 185, 165, 150])
plt.plot(xxx2,yyy2,'x',color='darkblue')


x3 = np.array([38.8, 42.3, 45.5, 50.5, 67.6, 74.3, 83.6, 94.6, 79.3, 67.7, 60, 56.2, 53.3, 49])
y3 = np.array([202.5, 220, 237.5, 265, 350, 387.5, 435, 492.5, 415, 350, 312.5, 295, 277.5, 255])
UI = (x3*y3).sum()/len(x3)
I2 = (x3**2).sum()/len(x3)
U2 = (y3**2).sum()/len(y3)
R = UI/I2
print(np.sqrt(1/(len(x3)-1)*(U2/I2-R**2)))
pp3, v3 = np.polyfit(x3, y3, deg=1, cov=True)
p3 = np.poly1d(pp3)
x = np.arange(0, 110, 0.01)
plt.plot(x, p3(x),label=r'$l = 50 см$')
xx3 = np.array([38.8, 42.3, 45.5, 50.5, 67.6, 74.3, 83.6, 94.6])
yy3 = np.array([202.5, 220, 237.5, 265, 350, 387.5, 435, 492.5])
plt.plot(xx3,yy3,'.',color='purple')
xxx3 = np.array([79.3, 67.7, 60, 56.2, 53.3, 49])
yyy3 = np.array([415, 350, 312.5, 295, 277.5, 255])
plt.plot(xxx3,yyy3,'x',color='purple')


plt.legend(loc='best', fontsize=12)
plt.xlabel(r'$I$, мА')
plt.ylabel(r'$U$, мВ')
plt.grid(True)
plt.tick_params("both", direction='in')
#plt.savefig('l2.pdf')
plt.show()
# Out:
# 0.00525114194196459
# 0.004937377017374901
# 0.005843621028014005
